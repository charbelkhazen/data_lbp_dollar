# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:\\Users\\user\\Downloads\\BDL.xlsx',header = 10 , index_col=0, nrows = 252)  #file foreign assets bdl
df
# Out:
#           Gold in Millions of LBP  Gold in Millions of US$  \
# Period
# 01/12/01                  3860774                     2561
# 01/01/02                  3926812                     2605
# 01/02/02                  4125620                     2737
# 01/03/02                  4224746                     2802
# 01/04/02                  4298014                     2851
# ...                           ...                      ...
# 31/07/22                 24520991                    16266
# 31/08/22                 24112113                    15995
# 30/09/22                 23244308                    15419
# 31/10/22                 22825003                    15141
# 30/11/22                 24465658                    16229
#
#           TOTAL (Excluding Gold) in Millions of LBP  \
# Period
# 01/12/01                                    6635152
# 01/01/02                                    6883270
# 01/02/02                                    6915759
# ...

# %%
df.plot( y = ["Gold in Millions of US$","Foreign Currencies in Millions of US$","Securities in Millions of US$"])
plt.axvline(x=df.index.get_loc('31/10/19'), linestyle='--',color= "red")  #plot oct-31-19
plt.axvline(x=df.index.get_loc('01/05/16'), linestyle='--',color= "black")  #plot  may 2016 - financial engineering 
plt.show()
