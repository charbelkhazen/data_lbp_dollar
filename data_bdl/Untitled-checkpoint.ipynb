# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_excel('C:\\Users\\user\\Downloads\\BDL.xlsx',header = 10 , index_col=0, nrows = 252)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df.plot( y = ["Gold in Millions of US$","Foreign Currencies in Millions of US$","Securities in Millions of US$"], kind = "line")
# Out:
# <AxesSubplot:xlabel='Period'>
